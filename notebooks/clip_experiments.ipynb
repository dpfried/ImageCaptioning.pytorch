# %%
pwd
# Out:
# '/home/dfried/projects/ImageCaptioning.pytorch/notebooks'

# %%
import os

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '7'

# %%
cd /home/dfried/projects/ImageCaptioning.pytorch
# Out:
# /home/dfried/projects/ImageCaptioning.pytorch

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import argparse
import captioning.utils.opts as opts
import captioning.utils.misc as utils
import captioning.models as models
from captioning.utils import eval_utils

# %%
from captioning.data.dataloader import NearestNeighborIndex
from captioning.data.dataloader import DataLoader

# %%
parser = argparse.ArgumentParser()
opts.add_eval_options(parser)
opts.add_diversity_opts(parser)

# %%
opt = parser.parse_args([])

# %%
model_fname = 'models/updown/model-best.pth'
infos_fname = 'models/updown/infos_tds-best.pkl'

# %%
with open(infos_fname, 'rb') as f:
    infos = utils.pickle_load(f)
infos.keys()
# Out:
# dict_keys(['vocab', 'opt', 'best_val_score', 'iter', 'iterators', 'epoch', 'split_ix'])

# %%
replace = ['input_fc_dir', 'input_att_dir', 'input_box_dir', 'input_label_h5', 'input_json', 'batch_size', 'id']
ignore = ['start_from']

for k in vars(infos['opt']).keys():
    if k in replace:
        setattr(opt, k, getattr(opt, k) or getattr(infos['opt'], k, ''))
    elif k not in ignore:
        if not k in vars(opt):
            vars(opt).update({k: vars(infos['opt'])[k]}) # copy over options from model

# %%
opt.max_images_per_split = None
opt.num_workers = 0

# %%
import torch

# %%
from clip import clip

# %%
from PIL import Image

# %%
device = 'cuda'

# %%
clip_model, clip_transform = clip.load("ViT-B/32")
clip_model = clip_model.to(device)

# %%
loader = DataLoader(opt, shuffle_override=False, wrap_override=False)
# Out:
# DataLoader loading json file:  data/cocotalk.json
# vocab size is  9487
# DataLoader loading h5 file:  data/cocobu_fc data/cocobu_att data/cocotalk_box data/cocotalk_label.h5
# max sequence length in data is 16
# read 123287 image features
# assigned 113287 images to split train
# assigned 5000 images to split val
# assigned 5000 images to split test

# %%
vocab = loader.get_vocab()

# %%
def wrap_tag(tag, inner):
    return f'<{tag}>{inner}</{tag}>'

def image_html(image_path, width=300, border=False):
    if border:
        style = ' style="border: 5px solid #0FF" '
    else:
        style = ''
    return f'<img width={width} src="{image_path}" {style}></img>'

def captions_html(captions):
    #return wrap_tag('p', '<br>'.join(' '.join(cap) for cap in captions))
    return wrap_tag('ol', ''.join(wrap_tag('li', cap) for cap in captions))

def images_html(image_paths, width=300, num_per_row=5, target=None, captions=None):
    rows = []
    for ix in range(0, len(image_paths), num_per_row):
        items = [wrap_tag('td', image_html(image_paths[image_ix], width=width, border=image_ix == target)) 
                 for image_ix in range(ix, ix+num_per_row) if image_ix < len(image_paths)]
        rows.append(wrap_tag('tr', ''.join(items)))
        if captions is not None:
            cap_html = [
                wrap_tag('td', captions_html(captions[image_ix]))
                for image_ix in range(ix, ix+num_per_row)
                if image_ix < len(image_paths)
            ]
            rows.append(wrap_tag('tr', ''.join(cap_html)))
    return wrap_tag('table', ''.join(rows))

def display_images(image_paths, width=300, num_per_row=5, target=None, captions=None):
    display(HTML(images_html(image_paths, width=width, num_per_row=num_per_row, target=target, captions=captions)))

# %%
def get_captions_from_batch(data):
    batch_captions = []
    for batch_labels in data['labels']:
        instance_captions = []
        for img_labels in batch_labels:
            caption = ' '.join([vocab[str(ix.item())] for ix in img_labels if ix != 0])
            instance_captions.append(caption)
        batch_captions.append(instance_captions)
    return batch_captions

# %%
def score_clip(image, text):
    with torch.no_grad():
        image_features = clip_model.encode_image(image)
        text_features = clip_model.encode_text(text)

        logits_per_image, logits_per_text = clip_model(image, text)
        probs = logits_per_image.softmax(dim=-1)
    return probs

# %%
import random

# %%
def shuffled(lst):
    lst = lst.copy()
    random.shuffle(lst)
    return lst

# %%
batch = next(loader.iters['val'])

# %%
batch['infos'][0]['file_path']
# Out:
# 'val2014/COCO_val2014_000000184613.jpg'

# %%
from itertools import groupby

# %%
def display_stuff(batch, ix, distractors=['PERSON', 'WOMAN', 'MAN', 'CAMERA', 'TV', 'DOG', 'BANANA', 'LEFT'], group_length=False):
    fpath = batch['infos'][ix]['file_path']
    captions = get_captions_from_batch(batch)[ix]
    
    image = clip_transform(Image.open(fpath)).unsqueeze(0).to(device)
    display_images([fpath], captions=[captions])
    for cap in captions:
        cap_split = cap.split()
        candidates = [cap]
        # shuffle
        # for _ in range(10):
        #     candidates.append(' '.join(shuffled(cap_split)))
        for ix in range(len(cap_split)):
            candidates.append(' '.join(cap_split[:ix]))
            for distractor in distractors:
                candidates.append(' '.join(cap_split[:ix] + [distractor]))
        text = clip.tokenize([cap.lower() for cap in candidates]).to(device)
        scored = zip(candidates, score_clip(image, text).detach().cpu().flatten().numpy())
        if group_length:
            groups = [list(g) for k, g in groupby(sorted(scored, key=lambda t: len(t[0].split())), key=lambda t: len(t[0].split()))]
        else:
            groups = [scored]
        for group in groups:
            scored = sorted(group, key=lambda t: t[1], reverse=False)
            for cap, score in scored:
                print(f'{score:.4f} {cap}')
            print()
        print()
        print("----")
        print()

# %%
pdb on
# Out:
# Automatic pdb calling has been turned ON

# %%
display_stuff(batch, 0, group_length=True)
# Out:
# <table><tr><td><img width=300 src="val2014/COCO_val2014_000000184613.jpg" ></img></td></tr><tr><td><ol><li>a child holding a flowered umbrella and petting a yak</li><li>a young man holding an umbrella next to a herd of cattle</li><li>a young boy barefoot holding an umbrella touching the horn of a cow</li><li>a young boy with an umbrella who is touching the horn of a cow</li><li>a boy holding an umbrella while standing next to livestock</li></ol></td></tr></table>
# 0.0000
#
# 0.0000 TV
# 0.0000 DOG
# 0.0000 MAN
# 0.0000 a
# 0.0000 CAMERA
# 0.0000 LEFT
# 0.0000 WOMAN
# 0.0000 PERSON
# 0.0000 BANANA
#
# 0.0000 a WOMAN
# 0.0000 a MAN
# 0.0000 a DOG
# 0.0000 a TV
# 0.0000 a BANANA
# 0.0000 a LEFT
# 0.0000 a PERSON
# 0.0000 a CAMERA
# 0.0000 a child
#
# 0.0000 a child TV
# 0.0000 a child BANANA
# 0.0000 a child DOG
# 0.0000 a child CAMERA
# 0.0000 a child LEFT
# 0.0000 a child WOMAN
# 0.0001 a child PERSON
# 0.0001 a child MAN
# 0.0007 a child holding
#
# 0.0001 a child holding TV
# 0.0001 a child holding BANANA
# 0.0001 a child holding WOMAN
# 0.0001 a child holding DOG
# 0.0006 a child holding a
# 0.0006 a child holding MAN
# 0.0008 a child holding PERSON
# 0.0008 a child holding LEFT
# 0.0012 a child holding CAMERA
#
# 0.0000 a child holding a TV
# 0.0001 a child holding a BANANA
# 0.0001 a child holding a WOMAN
# 0.0001 a child holding a DOG
# 0.0002 a child holding a flowered
# 0.0004 a child holding a LEFT
# 0.0005 a child holding a PERSON
# 0.0005 a child holding a MAN
# 0.0007 a child holding a CAMERA
#
# 0.0000 a child holding a flowered TV
# 0.0001 a child holding a flowered BANANA
# 0.0001 a child holding a flowered DOG
# 0.0002 a child holding a flowered LEFT
# 0.0004 a child holding a flowered WOMAN
# 0.0004 a child holding a flowered MAN
# 0.0005 a child holding a flowered CAMERA
# 0.0013 a child holding a flowered PERSON
# 0.0120 a child holding a flowered umbrella
#
# 0.0021 a child holding a flowered umbrella DOG
# 0.0024 a child holding a flowered umbrella and
# 0.0061 a child holding a flowered umbrella PERSON
# 0.0067 a child holding a flowered umbrella TV
# 0.0071 a child holding a flowered umbrella BANANA
# 0.0092 a child holding a flowered umbrella MAN
# 0.0101 a child holding a flowered umbrella WOMAN
# 0.0178 a child holding a flowered umbrella LEFT
# 0.0198 a child holding a flowered umbrella CAMERA
#
# 0.0046 a child holding a flowered umbrella and DOG
# 0.0083 a child holding a flowered umbrella and TV
# 0.0100 a child holding a flowered umbrella and WOMAN
# 0.0143 a child holding a flowered umbrella and BANANA
# 0.0157 a child holding a flowered umbrella and MAN
# 0.0157 a child holding a flowered umbrella and LEFT
# 0.0204 a child holding a flowered umbrella and petting
# 0.0214 a child holding a flowered umbrella and CAMERA
# 0.0235 a child holding a flowered umbrella and PERSON
#
# 0.0032 a child holding a flowered umbrella and petting TV
# 0.0040 a child holding a flowered umbrella and petting DOG
# 0.0095 a child holding a flowered umbrella and petting a
# 0.0128 a child holding a flowered umbrella and petting PERSON
# 0.0128 a child holding a flowered umbrella and petting WOMAN
# 0.0128 a child holding a flowered umbrella and petting BANANA
# 0.0130 a child holding a flowered umbrella and petting CAMERA
# 0.0172 a child holding a flowered umbrella and petting MAN
# 0.0247 a child holding a flowered umbrella and petting LEFT
#
# 0.0038 a child holding a flowered umbrella and petting a DOG
# 0.0061 a child holding a flowered umbrella and petting a TV
# 0.0109 a child holding a flowered umbrella and petting a WOMAN
# 0.0124 a child holding a flowered umbrella and petting a BANANA
# 0.0154 a child holding a flowered umbrella and petting a PERSON
# 0.0255 a child holding a flowered umbrella and petting a LEFT
# 0.0280 a child holding a flowered umbrella and petting a MAN
# 0.0302 a child holding a flowered umbrella and petting a CAMERA
# 0.5195 a child holding a flowered umbrella and petting a yak
#
#
# ----
#
# 0.0000
#
# 0.0000 MAN
# 0.0000 TV
# 0.0000 DOG
# 0.0000 PERSON
# 0.0000 WOMAN
# 0.0000 CAMERA
# 0.0000 BANANA
# 0.0000 LEFT
# 0.0000 a
#
# 0.0000 a WOMAN
# 0.0000 a MAN
# 0.0000 a TV
# 0.0000 a DOG
# 0.0000 a BANANA
# 0.0000 a LEFT
# 0.0000 a PERSON
# 0.0000 a CAMERA
# 0.0000 a young
#
# 0.0000 a young TV
# 0.0000 a young DOG
# 0.0000 a young BANANA
# 0.0000 a young WOMAN
# 0.0000 a young LEFT
# 0.0000 a young MAN
# 0.0000 a young man
# 0.0000 a young CAMERA
# 0.0000 a young PERSON
#
# 0.0000 a young man TV
# 0.0000 a young man DOG
# 0.0000 a young man LEFT
# 0.0000 a young man MAN
# 0.0000 a young man BANANA
# 0.0000 a young man WOMAN
# 0.0000 a young man PERSON
# 0.0000 a young man CAMERA
# 0.0000 a young man holding
#
# 0.0000 a young man holding TV
# 0.0000 a young man holding WOMAN
# 0.0000 a young man holding DOG
# 0.0000 a young man holding CAMERA
# 0.0000 a young man holding MAN
# 0.0000 a young man holding BANANA
# 0.0000 a young man holding PERSON
# 0.0000 a young man holding an
# 0.0000 a young man holding LEFT
#
# 0.0000 a young man holding an TV
# 0.0000 a young man holding an WOMAN
# 0.0000 a young man holding an DOG
# 0.0000 a young man holding an CAMERA
# 0.0000 a young man holding an MAN
# 0.0000 a young man holding an BANANA
# 0.0000 a young man holding an PERSON
# 0.0000 a young man holding an LEFT
# 0.0001 a young man holding an umbrella
#
# 0.0000 a young man holding an umbrella LEFT
# 0.0000 a young man holding an umbrella next
# 0.0000 a young man holding an umbrella TV
# 0.0000 a young man holding an umbrella WOMAN
# 0.0001 a young man holding an umbrella DOG
# 0.0001 a young man holding an umbrella MAN
# 0.0001 a young man holding an umbrella PERSON
# 0.0001 a young man holding an umbrella CAMERA
# 0.0001 a young man holding an umbrella BANANA
#
# 0.0000 a young man holding an umbrella next WOMAN
# 0.0000 a young man holding an umbrella next to
# 0.0000 a young man holding an umbrella next LEFT
# 0.0000 a young man holding an umbrella next TV
# 0.0000 a young man holding an umbrella next CAMERA
# 0.0000 a young man holding an umbrella next MAN
# 0.0001 a young man holding an umbrella next PERSON
# 0.0001 a young man holding an umbrella next BANANA
# 0.0001 a young man holding an umbrella next DOG
#
# 0.0000 a young man holding an umbrella next to WOMAN
# 0.0000 a young man holding an umbrella next to LEFT
# 0.0000 a young man holding an umbrella next to TV
# 0.0000 a young man holding an umbrella next to CAMERA
# 0.0000 a young man holding an umbrella next to MAN
# 0.0000 a young man holding an umbrella next to PERSON
# 0.0000 a young man holding an umbrella next to DOG
# 0.0000 a young man holding an umbrella next to a
# 0.0001 a young man holding an umbrella next to BANANA
#
# 0.0000 a young man holding an umbrella next to a WOMAN
# 0.0000 a young man holding an umbrella next to a TV
# 0.0000 a young man holding an umbrella next to a MAN
# 0.0000 a young man holding an umbrella next to a CAMERA
# 0.0000 a young man holding an umbrella next to a LEFT
# 0.0000 a young man holding an umbrella next to a PERSON
# 0.0000 a young man holding an umbrella next to a BANANA
# 0.0000 a young man holding an umbrella next to a DOG
# 0.0938 a young man holding an umbrella next to a herd
#
# 0.0295 a young man holding an umbrella next to a herd CAMERA
# 0.0429 a young man holding an umbrella next to a herd BANANA
# 0.0429 a young man holding an umbrella next to a herd of
# 0.0443 a young man holding an umbrella next to a herd WOMAN
# 0.0605 a young man holding an umbrella next to a herd MAN
# 0.0828 a young man holding an umbrella next to a herd LEFT
# 0.0909 a young man holding an umbrella next to a herd TV
# 0.1063 a young man holding an umbrella next to a herd PERSON
# 0.1204 a young man holding an umbrella next to a herd DOG
#
# 0.0082 a young man holding an umbrella next to a herd of WOMAN
# 0.0123 a young man holding an umbrella next to a herd of MAN
# 0.0197 a young man holding an umbrella next to a herd of PERSON
# 0.0203 a young man holding an umbrella next to a herd of DOG
# 0.0245 a young man holding an umbrella next to a herd of LEFT
# 0.0252 a young man holding an umbrella next to a herd of BANANA
# 0.0277 a young man holding an umbrella next to a herd of CAMERA
# 0.0334 a young man holding an umbrella next to a herd of TV
# 0.1131 a young man holding an umbrella next to a herd of cattle
#
#
# ----
#
# 0.0000
#
# 0.0000 TV
# 0.0000 MAN
# 0.0000 DOG
# 0.0000 a
# 0.0000 WOMAN
# 0.0000 CAMERA
# 0.0000 LEFT
# 0.0000 PERSON
# 0.0000 BANANA
#
# 0.0000 a WOMAN
# 0.0000 a MAN
# 0.0000 a TV
# 0.0000 a DOG
# 0.0000 a BANANA
# 0.0000 a LEFT
# 0.0000 a PERSON
# 0.0000 a CAMERA
# 0.0000 a young
#
# 0.0000 a young TV
# 0.0000 a young DOG
# 0.0000 a young BANANA
# 0.0000 a young WOMAN
# 0.0000 a young LEFT
# 0.0000 a young MAN
# 0.0000 a young CAMERA
# 0.0000 a young PERSON
# 0.0000 a young boy
#
# 0.0000 a young boy DOG
# 0.0000 a young boy TV
# 0.0000 a young boy BANANA
# 0.0000 a young boy MAN
# 0.0000 a young boy LEFT
# 0.0000 a young boy WOMAN
# 0.0000 a young boy PERSON
# 0.0000 a young boy CAMERA
# 0.0000 a young boy barefoot
#
# 0.0000 a young boy barefoot TV
# 0.0000 a young boy barefoot BANANA
# 0.0000 a young boy barefoot LEFT
# 0.0000 a young boy barefoot MAN
# 0.0000 a young boy barefoot DOG
# 0.0001 a young boy barefoot holding
# 0.0001 a young boy barefoot PERSON
# 0.0002 a young boy barefoot CAMERA
# 0.0003 a young boy barefoot WOMAN
#
# 0.0000 a young boy barefoot holding TV
# 0.0000 a young boy barefoot holding WOMAN
# 0.0000 a young boy barefoot holding DOG
# 0.0000 a young boy barefoot holding BANANA
# 0.0001 a young boy barefoot holding an
# 0.0001 a young boy barefoot holding LEFT
# 0.0001 a young boy barefoot holding MAN
# 0.0001 a young boy barefoot holding CAMERA
# 0.0002 a young boy barefoot holding PERSON
#
# 0.0000 a young boy barefoot holding an TV
# 0.0000 a young boy barefoot holding an WOMAN
# 0.0000 a young boy barefoot holding an DOG
# 0.0000 a young boy barefoot holding an BANANA
# 0.0000 a young boy barefoot holding an CAMERA
# 0.0001 a young boy barefoot holding an LEFT
# 0.0001 a young boy barefoot holding an MAN
# 0.0002 a young boy barefoot holding an PERSON
# 0.0008 a young boy barefoot holding an umbrella
#
# 0.0004 a young boy barefoot holding an umbrella DOG
# 0.0005 a young boy barefoot holding an umbrella BANANA
# 0.0006 a young boy barefoot holding an umbrella LEFT
# 0.0007 a young boy barefoot holding an umbrella TV
# 0.0009 a young boy barefoot holding an umbrella touching
# 0.0010 a young boy barefoot holding an umbrella WOMAN
# 0.0013 a young boy barefoot holding an umbrella PERSON
# 0.0013 a young boy barefoot holding an umbrella MAN
# 0.0018 a young boy barefoot holding an umbrella CAMERA
#
# 0.0002 a young boy barefoot holding an umbrella touching DOG
# 0.0003 a young boy barefoot holding an umbrella touching TV
# 0.0003 a young boy barefoot holding an umbrella touching WOMAN
# 0.0004 a young boy barefoot holding an umbrella touching BANANA
# 0.0005 a young boy barefoot holding an umbrella touching MAN
# 0.0006 a young boy barefoot holding an umbrella touching LEFT
# 0.0009 a young boy barefoot holding an umbrella touching CAMERA
# 0.0011 a young boy barefoot holding an umbrella touching PERSON
# 0.0017 a young boy barefoot holding an umbrella touching the
#
# 0.0002 a young boy barefoot holding an umbrella touching the TV
# 0.0004 a young boy barefoot holding an umbrella touching the LEFT
# 0.0004 a young boy barefoot holding an umbrella touching the DOG
# 0.0005 a young boy barefoot holding an umbrella touching the WOMAN
# 0.0006 a young boy barefoot holding an umbrella touching the BANANA
# 0.0010 a young boy barefoot holding an umbrella touching the MAN
# 0.0014 a young boy barefoot holding an umbrella touching the CAMERA
# 0.0014 a young boy barefoot holding an umbrella touching the PERSON
# 0.0083 a young boy barefoot holding an umbrella touching the horn
#
# 0.0017 a young boy barefoot holding an umbrella touching the horn TV
# 0.0048 a young boy barefoot holding an umbrella touching the horn BANANA
# 0.0055 a young boy barefoot holding an umbrella touching the horn CAMERA
# 0.0065 a young boy barefoot holding an umbrella touching the horn LEFT
# 0.0100 a young boy barefoot holding an umbrella touching the horn WOMAN
# 0.0139 a young boy barefoot holding an umbrella touching the horn PERSON
# 0.0166 a young boy barefoot holding an umbrella touching the horn of
# 0.0194 a young boy barefoot holding an umbrella touching the horn MAN
# 0.0351 a young boy barefoot holding an umbrella touching the horn DOG
#
# 0.0035 a young boy barefoot holding an umbrella touching the horn of TV
# 0.0043 a young boy barefoot holding an umbrella touching the horn of LEFT
# 0.0045 a young boy barefoot holding an umbrella touching the horn of WOMAN
# 0.0060 a young boy barefoot holding an umbrella touching the horn of BANANA
# 0.0077 a young boy barefoot holding an umbrella touching the horn of MAN
# 0.0100 a young boy barefoot holding an umbrella touching the horn of CAMERA
# 0.0117 a young boy barefoot holding an umbrella touching the horn of a
# 0.0139 a young boy barefoot holding an umbrella touching the horn of PERSON
# 0.0161 a young boy barefoot holding an umbrella touching the horn of DOG
#
# 0.0034 a young boy barefoot holding an umbrella touching the horn of a WOMAN
# 0.0035 a young boy barefoot holding an umbrella touching the horn of a BANANA
# 0.0035 a young boy barefoot holding an umbrella touching the horn of a TV
# 0.0047 a young boy barefoot holding an umbrella touching the horn of a LEFT
# 0.0055 a young boy barefoot holding an umbrella touching the horn of a DOG
# 0.0056 a young boy barefoot holding an umbrella touching the horn of a CAMERA
# 0.0069 a young boy barefoot holding an umbrella touching the horn of a MAN
# 0.0171 a young boy barefoot holding an umbrella touching the horn of a PERSON
# 0.7266 a young boy barefoot holding an umbrella touching the horn of a cow
#
#
# ----
# 0.0000
#
# 0.0000 TV
# 0.0000 DOG
# 0.0000 MAN
# 0.0000 LEFT
# 0.0000 a
# 0.0000 CAMERA
# 0.0000 WOMAN
# 0.0000 PERSON
# 0.0000 BANANA
#
# 0.0000 a WOMAN
# 0.0000 a MAN
# 0.0000 a TV
# 0.0000 a DOG
# 0.0000 a BANANA
# 0.0000 a LEFT
# 0.0000 a PERSON
# 0.0000 a CAMERA
# 0.0000 a young
#
# 0.0000 a young TV
# 0.0000 a young DOG
# 0.0000 a young BANANA
# 0.0000 a young WOMAN
# 0.0000 a young LEFT
# 0.0000 a young MAN
# 0.0000 a young CAMERA
# 0.0000 a young PERSON
# 0.0000 a young boy
#
# 0.0000 a young boy DOG
# 0.0000 a young boy TV
# 0.0000 a young boy BANANA
# 0.0000 a young boy MAN
# 0.0000 a young boy LEFT
# 0.0000 a young boy WOMAN
# 0.0000 a young boy with
# 0.0000 a young boy PERSON
# 0.0000 a young boy CAMERA
#
# 0.0000 a young boy with an
# 0.0000 a young boy with WOMAN
# 0.0000 a young boy with TV
# 0.0000 a young boy with DOG
# 0.0000 a young boy with LEFT
# 0.0000 a young boy with MAN
# 0.0001 a young boy with PERSON
# 0.0001 a young boy with BANANA
# 0.0001 a young boy with CAMERA
#
# 0.0000 a young boy with an WOMAN
# 0.0000 a young boy with an TV
# 0.0000 a young boy with an DOG
# 0.0000 a young boy with an MAN
# 0.0000 a young boy with an BANANA
# 0.0000 a young boy with an LEFT
# 0.0000 a young boy with an PERSON
# 0.0001 a young boy with an CAMERA
# 0.0012 a young boy with an umbrella
#
# 0.0004 a young boy with an umbrella MAN
# 0.0005 a young boy with an umbrella BANANA
# 0.0006 a young boy with an umbrella who
# 0.0006 a young boy with an umbrella WOMAN
# 0.0007 a young boy with an umbrella DOG
# 0.0009 a young boy with an umbrella LEFT
# 0.0011 a young boy with an umbrella PERSON
# 0.0021 a young boy with an umbrella TV
# 0.0039 a young boy with an umbrella CAMERA
#
# 0.0002 a young boy with an umbrella who MAN
# 0.0005 a young boy with an umbrella who WOMAN
# 0.0006 a young boy with an umbrella who TV
# 0.0006 a young boy with an umbrella who LEFT
# 0.0009 a young boy with an umbrella who BANANA
# 0.0010 a young boy with an umbrella who is
# 0.0013 a young boy with an umbrella who DOG
# 0.0015 a young boy with an umbrella who PERSON
# 0.0031 a young boy with an umbrella who CAMERA
#
# 0.0002 a young boy with an umbrella who is TV
# 0.0005 a young boy with an umbrella who is BANANA
# 0.0006 a young boy with an umbrella who is touching
# 0.0010 a young boy with an umbrella who is DOG
# 0.0013 a young boy with an umbrella who is LEFT
# 0.0017 a young boy with an umbrella who is WOMAN
# 0.0022 a young boy with an umbrella who is MAN
# 0.0022 a young boy with an umbrella who is PERSON
# 0.0032 a young boy with an umbrella who is CAMERA
#
# 0.0001 a young boy with an umbrella who is touching WOMAN
# 0.0002 a young boy with an umbrella who is touching MAN
# 0.0003 a young boy with an umbrella who is touching TV
# 0.0003 a young boy with an umbrella who is touching DOG
# 0.0005 a young boy with an umbrella who is touching PERSON
# 0.0006 a young boy with an umbrella who is touching BANANA
# 0.0008 a young boy with an umbrella who is touching LEFT
# 0.0010 a young boy with an umbrella who is touching the
# 0.0019 a young boy with an umbrella who is touching CAMERA
#
# 0.0002 a young boy with an umbrella who is touching the TV
# 0.0002 a young boy with an umbrella who is touching the WOMAN
# 0.0003 a young boy with an umbrella who is touching the MAN
# 0.0005 a young boy with an umbrella who is touching the PERSON
# 0.0005 a young boy with an umbrella who is touching the DOG
# 0.0008 a young boy with an umbrella who is touching the LEFT
# 0.0008 a young boy with an umbrella who is touching the BANANA
# 0.0021 a young boy with an umbrella who is touching the CAMERA
# 0.0131 a young boy with an umbrella who is touching the horn
#
# 0.0021 a young boy with an umbrella who is touching the horn TV
# 0.0074 a young boy with an umbrella who is touching the horn WOMAN
# 0.0074 a young boy with an umbrella who is touching the horn LEFT
# 0.0099 a young boy with an umbrella who is touching the horn PERSON
# 0.0107 a young boy with an umbrella who is touching the horn BANANA
# 0.0120 a young boy with an umbrella who is touching the horn CAMERA
# 0.0133 a young boy with an umbrella who is touching the horn MAN
# 0.0230 a young boy with an umbrella who is touching the horn of
# 0.0335 a young boy with an umbrella who is touching the horn DOG
#
# 0.0038 a young boy with an umbrella who is touching the horn of WOMAN
# 0.0050 a young boy with an umbrella who is touching the horn of TV
# 0.0107 a young boy with an umbrella who is touching the horn of LEFT
# 0.0109 a young boy with an umbrella who is touching the horn of MAN
# 0.0109 a young boy with an umbrella who is touching the horn of BANANA
# 0.0114 a young boy with an umbrella who is touching the horn of a
# 0.0151 a young boy with an umbrella who is touching the horn of PERSON
# 0.0261 a young boy with an umbrella who is touching the horn of CAMERA
# 0.0261 a young boy with an umbrella who is touching the horn of DOG
#
# 0.0020 a young boy with an umbrella who is touching the horn of a WOMAN
# 0.0045 a young boy with an umbrella who is touching the horn of a BANANA
# 0.0050 a young boy with an umbrella who is touching the horn of a TV
# 0.0057 a young boy with an umbrella who is touching the horn of a DOG
# 0.0069 a young boy with an umbrella who is touching the horn of a MAN
# 0.0095 a young boy with an umbrella who is touching the horn of a LEFT
# 0.0107 a young boy with an umbrella who is touching the horn of a PERSON
# 0.0142 a young boy with an umbrella who is touching the horn of a CAMERA
# 0.6426 a young boy with an umbrella who is touching the horn of a cow
#
#
# ----
#
# 0.0000
#
# 0.0000 TV
# 0.0000 DOG
# 0.0000 MAN
# 0.0000 a
# 0.0000 CAMERA
# 0.0000 LEFT
# 0.0000 WOMAN
# 0.0000 PERSON
# 0.0000 BANANA
#
# 0.0000 a WOMAN
# 0.0000 a MAN
# 0.0000 a DOG
# 0.0000 a TV
# 0.0000 a BANANA
# 0.0000 a LEFT
# 0.0000 a boy
# 0.0000 a PERSON
# 0.0000 a CAMERA
#
# 0.0000 a boy TV
# 0.0000 a boy BANANA
# 0.0000 a boy MAN
# 0.0000 a boy DOG
# 0.0000 a boy LEFT
# 0.0000 a boy WOMAN
# 0.0000 a boy PERSON
# 0.0000 a boy CAMERA
# 0.0001 a boy holding
#
# 0.0000 a boy holding TV
# 0.0000 a boy holding WOMAN
# 0.0000 a boy holding DOG
# 0.0000 a boy holding BANANA
# 0.0001 a boy holding MAN
# 0.0002 a boy holding CAMERA
# 0.0002 a boy holding PERSON
# 0.0003 a boy holding an
# 0.0004 a boy holding LEFT
#
# 0.0000 a boy holding an TV
# 0.0000 a boy holding an BANANA
# 0.0000 a boy holding an DOG
# 0.0000 a boy holding an WOMAN
# 0.0001 a boy holding an MAN
# 0.0001 a boy holding an CAMERA
# 0.0001 a boy holding an PERSON
# 0.0002 a boy holding an LEFT
# 0.0024 a boy holding an umbrella
#
# 0.0005 a boy holding an umbrella BANANA
# 0.0012 a boy holding an umbrella DOG
# 0.0015 a boy holding an umbrella MAN
# 0.0020 a boy holding an umbrella WOMAN
# 0.0020 a boy holding an umbrella TV
# 0.0021 a boy holding an umbrella PERSON
# 0.0022 a boy holding an umbrella LEFT
# 0.0056 a boy holding an umbrella while
# 0.0067 a boy holding an umbrella CAMERA
#
# 0.0004 a boy holding an umbrella while standing
# 0.0005 a boy holding an umbrella while TV
# 0.0006 a boy holding an umbrella while LEFT
# 0.0006 a boy holding an umbrella while WOMAN
# 0.0010 a boy holding an umbrella while MAN
# 0.0011 a boy holding an umbrella while DOG
# 0.0013 a boy holding an umbrella while BANANA
# 0.0026 a boy holding an umbrella while PERSON
# 0.0050 a boy holding an umbrella while CAMERA
#
# 0.0001 a boy holding an umbrella while standing TV
# 0.0002 a boy holding an umbrella while standing WOMAN
# 0.0002 a boy holding an umbrella while standing next
# 0.0002 a boy holding an umbrella while standing MAN
# 0.0003 a boy holding an umbrella while standing PERSON
# 0.0004 a boy holding an umbrella while standing BANANA
# 0.0005 a boy holding an umbrella while standing LEFT
# 0.0006 a boy holding an umbrella while standing CAMERA
# 0.0007 a boy holding an umbrella while standing DOG
#
# 0.0000 a boy holding an umbrella while standing next WOMAN
# 0.0001 a boy holding an umbrella while standing next TV
# 0.0001 a boy holding an umbrella while standing next MAN
# 0.0001 a boy holding an umbrella while standing next LEFT
# 0.0002 a boy holding an umbrella while standing next BANANA
# 0.0002 a boy holding an umbrella while standing next PERSON
# 0.0003 a boy holding an umbrella while standing next to
# 0.0003 a boy holding an umbrella while standing next CAMERA
# 0.0004 a boy holding an umbrella while standing next DOG
#
# 0.0001 a boy holding an umbrella while standing next to TV
# 0.0001 a boy holding an umbrella while standing next to MAN
# 0.0001 a boy holding an umbrella while standing next to WOMAN
# 0.0002 a boy holding an umbrella while standing next to PERSON
# 0.0002 a boy holding an umbrella while standing next to LEFT
# 0.0002 a boy holding an umbrella while standing next to BANANA
# 0.0003 a boy holding an umbrella while standing next to DOG
# 0.0004 a boy holding an umbrella while standing next to CAMERA
# 0.9526 a boy holding an umbrella while standing next to livestock
#
#
# ----

# %%
display_stuff(batch, 8)
# Out:
# <table><tr><td><img width=300 src="val2014/COCO_val2014_000000472621.jpg" ></img></td></tr><tr><td><ol><li>an elegant bathroom features a tub sink mirror and decorations</li><li>an old fashion above ground tub is shown with gold feet</li><li>a lovely vintage styled bathroom with a great claw footed tub</li><li>bathroom with a pedestal sink and claw foot bathtub</li><li>a claw foot tub is in a large bathroom near a pedestal sink</li></ol></td></tr></table>
# 0.1388 an elegant bathroom features a tub WOMAN
# 0.0869 an elegant bathroom features
# 0.0816 an elegant bathroom features LEFT
# 0.0720 an elegant bathroom features a LEFT
# 0.0676 an elegant bathroom features a tub PERSON
# 0.0676 an elegant bathroom features a tub LEFT
# 0.0597 an elegant bathroom features a tub
# 0.0330 an elegant bathroom features a
# 0.0310 an elegant bathroom features a tub sink WOMAN
# 0.0265 an elegant bathroom features a WOMAN
# 0.0206 an elegant bathroom features a tub sink mirror and WOMAN
# 0.0188 an elegant bathroom features a tub sink PERSON
# 0.0166 an elegant bathroom features a MAN
# 0.0161 an elegant bathroom features a PERSON
# 0.0156 an elegant bathroom features a tub TV
# 0.0151 an elegant bathroom features a tub MAN
# 0.0137 an elegant bathroom
# 0.0133 an elegant bathroom features a tub BANANA
# 0.0131 an elegant bathroom features WOMAN
# 0.0125 an elegant bathroom features a tub sink
# 0.0125 an elegant bathroom features a tub sink LEFT
# 0.0112 an elegant bathroom features a CAMERA
# 0.0110 an elegant bathroom features a tub sink mirror and PERSON
# 0.0105 an elegant bathroom features a tub sink mirror WOMAN
# 0.0102 an elegant bathroom features CAMERA
# 0.0102 an elegant bathroom features a tub sink mirror and MAN
# 0.0097 an elegant bathroom features a TV
# 0.0087 an elegant bathroom features TV
# 0.0087 an elegant bathroom features a tub CAMERA
# 0.0078 an elegant bathroom features MAN
# 0.0077 an elegant bathroom features a BANANA
# 0.0071 an elegant bathroom features PERSON
# 0.0071 an elegant bathroom features a tub sink mirror and LEFT
# 0.0063 an elegant bathroom features a DOG
# 0.0062 an elegant bathroom features BANANA
# 0.0051 an elegant bathroom features a tub sink mirror and
# 0.0043 an elegant bathroom features a tub sink mirror and decorations
# 0.0043 an elegant bathroom features a tub sink mirror PERSON
# 0.0039 an elegant bathroom features a tub sink MAN
# 0.0031 an elegant bathroom features a tub sink TV
# 0.0028 an elegant bathroom features a tub sink mirror LEFT
# 0.0028 an elegant bathroom LEFT
# 0.0024 an elegant bathroom features a tub sink BANANA
# 0.0022 an elegant bathroom features a tub sink CAMERA
# 0.0021 an elegant bathroom features a tub DOG
# 0.0017 an elegant bathroom features a tub sink mirror and BANANA
# 0.0013 an elegant bathroom features a tub sink mirror CAMERA
# 0.0013 an elegant bathroom features a tub sink mirror
# 0.0012 an elegant bathroom features a tub sink mirror BANANA
# 0.0011 an elegant bathroom features DOG
# 0.0011 an elegant bathroom features a tub sink mirror and CAMERA
# 0.0009 an elegant bathroom features a tub sink mirror TV
# 0.0008 an elegant bathroom features a tub sink mirror and TV
# 0.0006 an elegant bathroom features a tub sink mirror and DOG
# 0.0006 an elegant bathroom features a tub sink mirror MAN
# 0.0003 an elegant bathroom TV
# 0.0003 an elegant bathroom features a tub sink DOG
# 0.0002 an elegant bathroom features a tub sink mirror DOG
# 0.0001 an elegant bathroom CAMERA
# 0.0000 an elegant bathroom BANANA
# 0.0000 an elegant bathroom WOMAN
# 0.0000 an elegant bathroom MAN
# 0.0000 an elegant bathroom PERSON
# 0.0000 an elegant TV
# 0.0000 an elegant bathroom DOG
# 0.0000 an elegant CAMERA
# 0.0000 an elegant
# 0.0000 an
# 0.0000 an elegant LEFT
# 0.0000
# 0.0000 PERSON
# 0.0000 WOMAN
# 0.0000 LEFT
# 0.0000 an CAMERA
# 0.0000 an TV
# 0.0000 an elegant PERSON
# 0.0000 an elegant BANANA
# 0.0000 MAN
# 0.0000 CAMERA
# 0.0000 TV
# 0.0000 DOG
# 0.0000 BANANA
# 0.0000 an PERSON
# 0.0000 an WOMAN
# 0.0000 an MAN
# 0.0000 an DOG
# 0.0000 an BANANA
# 0.0000 an LEFT
# 0.0000 an elegant WOMAN
# 0.0000 an elegant MAN
# 0.0000 an elegant DOG
#
# ----
#
# 0.1534 an old fashion above ground tub is shown with gold PERSON
# 0.1396 an old fashion above ground tub is shown with gold
# 0.1396 an old fashion above ground tub is shown with gold TV
# 0.1272 an old fashion above ground tub is shown with gold MAN
# 0.1022 an old fashion above ground tub is shown with gold BANANA
# 0.0902 an old fashion above ground tub is shown with gold LEFT
# 0.0640 an old fashion above ground tub is shown with gold WOMAN
# 0.0547 an old fashion above ground tub is shown with gold CAMERA
# 0.0547 an old fashion above ground tub is shown with gold DOG
# 0.0332 an old fashion above ground tub is shown with gold feet
# 0.0054 an old fashion above ground tub is shown with
# 0.0046 an old fashion above ground tub is shown with BANANA
# 0.0033 an old fashion above ground tub is shown with TV
# 0.0032 an old fashion above ground tub is shown MAN
# 0.0028 an old fashion above ground tub is shown BANANA
# 0.0028 an old fashion above ground tub is shown
# 0.0026 an old fashion above ground tub is shown with LEFT
# 0.0021 an old fashion above ground tub is shown PERSON
# 0.0019 an old fashion above ground tub is shown TV
# 0.0019 an old fashion above ground tub is shown LEFT
# 0.0017 an old fashion above ground tub is shown with CAMERA
# 0.0016 an old fashion above ground tub is shown with PERSON
# 0.0014 an old fashion above ground tub is shown with MAN
# 0.0012 an old fashion above ground tub is shown WOMAN
# 0.0011 an old fashion above ground tub is shown CAMERA
# 0.0006 an old fashion above ground tub is shown with WOMAN
# 0.0005 an old fashion above ground tub is shown DOG
# 0.0003 an old fashion above ground tub
# 0.0003 an old fashion above ground tub is shown with DOG
# 0.0003 an old fashion above ground tub is
# 0.0002 an old fashion above ground tub is PERSON
# 0.0002 an old fashion above ground tub is WOMAN
# 0.0002 an old fashion above ground tub is CAMERA
# 0.0001 an old fashion above ground tub is MAN
# 0.0001 an old fashion above ground tub LEFT
# 0.0001 an old fashion above ground tub is BANANA
# 0.0001 an old fashion above ground tub BANANA
# 0.0001 an old fashion above ground tub TV
# 0.0001 an old fashion above ground tub PERSON
# 0.0001 an old fashion above ground tub WOMAN
# 0.0001 an old fashion above ground tub is TV
# 0.0000 an old fashion above ground tub is LEFT
# 0.0000 an old fashion above ground tub MAN
# 0.0000 an old fashion above ground tub CAMERA
# 0.0000 an old fashion above ground tub is DOG
# 0.0000 an old fashion above ground tub DOG
# 0.0000 an old fashion above WOMAN
# 0.0000 an old fashion above LEFT
# 0.0000 an old fashion above
# 0.0000 an old fashion above MAN
# 0.0000 an
# 0.0000 an old fashion
# 0.0000 an old fashion LEFT
# 0.0000 an old fashion above PERSON
# 0.0000 an old fashion above CAMERA
# 0.0000 an old fashion above TV
# 0.0000 an old fashion above ground
# 0.0000 an old fashion above ground PERSON
# 0.0000 an old fashion above ground LEFT
# 0.0000
# 0.0000 PERSON
# 0.0000 WOMAN
# 0.0000 MAN
# 0.0000 CAMERA
# 0.0000 TV
# 0.0000 DOG
# 0.0000 BANANA
# 0.0000 LEFT
# 0.0000 an PERSON
# 0.0000 an WOMAN
# 0.0000 an MAN
# 0.0000 an CAMERA
# 0.0000 an TV
# 0.0000 an DOG
# 0.0000 an BANANA
# 0.0000 an LEFT
# 0.0000 an old
# 0.0000 an old PERSON
# 0.0000 an old WOMAN
# 0.0000 an old MAN
# 0.0000 an old CAMERA
# 0.0000 an old TV
# 0.0000 an old DOG
# 0.0000 an old BANANA
# 0.0000 an old LEFT
# 0.0000 an old fashion PERSON
# 0.0000 an old fashion WOMAN
# 0.0000 an old fashion MAN
# 0.0000 an old fashion CAMERA
# 0.0000 an old fashion TV
# 0.0000 an old fashion DOG
# 0.0000 an old fashion BANANA
# 0.0000 an old fashion above DOG
# 0.0000 an old fashion above BANANA
# 0.0000 an old fashion above ground WOMAN
# 0.0000 an old fashion above ground MAN
# 0.0000 an old fashion above ground CAMERA
# 0.0000 an old fashion above ground TV
# 0.0000 an old fashion above ground DOG
# 0.0000 an old fashion above ground BANANA
#
# ----
#
# 0.0602 a lovely vintage styled bathroom with a great LEFT
# 0.0565 a lovely vintage styled bathroom with a great
# 0.0499 a lovely vintage styled bathroom with LEFT
# 0.0427 a lovely vintage styled bathroom with PERSON
# 0.0420 a lovely vintage styled bathroom with a LEFT
# 0.0407 a lovely vintage styled bathroom with
# 0.0401 a lovely vintage styled bathroom with MAN
# 0.0348 a lovely vintage styled bathroom with a
# 0.0332 a lovely vintage styled bathroom with CAMERA
# 0.0332 a lovely vintage styled bathroom with a great CAMERA
# 0.0327 a lovely vintage styled bathroom with a great claw TV
# 0.0303 a lovely vintage styled bathroom with a great claw footed tub
# 0.0298 a lovely vintage styled bathroom with a great MAN
# 0.0289 a lovely vintage styled bathroom with a MAN
# 0.0267 a lovely vintage styled bathroom LEFT
# 0.0263 a lovely vintage styled bathroom with WOMAN
# 0.0263 a lovely vintage styled bathroom with a great claw LEFT
# 0.0243 a lovely vintage styled bathroom with BANANA
# 0.0243 a lovely vintage styled bathroom with a great claw footed LEFT
# 0.0221 a lovely vintage styled bathroom with a great PERSON
# 0.0208 a lovely vintage styled bathroom with a great TV
# 0.0205 a lovely vintage styled bathroom with a great claw
# 0.0189 a lovely vintage styled bathroom with a great BANANA
# 0.0186 a lovely vintage styled bathroom with a great claw footed
# 0.0184 a lovely vintage styled bathroom
# 0.0184 a lovely vintage styled bathroom with a CAMERA
# 0.0170 a lovely vintage styled bathroom with a WOMAN
# 0.0167 a lovely vintage styled bathroom with a great claw footed PERSON
# 0.0145 a lovely vintage styled bathroom with TV
# 0.0134 a lovely vintage styled bathroom with a BANANA
# 0.0124 a lovely vintage styled bathroom with a PERSON
# 0.0108 a lovely vintage styled bathroom with a great claw footed CAMERA
# 0.0106 a lovely vintage styled bathroom with a great claw footed TV
# 0.0101 a lovely vintage styled bathroom with a great claw footed BANANA
# 0.0098 a lovely vintage styled bathroom with a great claw CAMERA
# 0.0089 a lovely vintage styled bathroom with a great WOMAN
# 0.0081 a lovely vintage styled bathroom with a TV
# 0.0071 a lovely vintage styled bathroom with a great claw BANANA
# 0.0056 a lovely vintage styled bathroom with a great claw footed DOG
# 0.0051 a lovely vintage styled bathroom with a great claw footed WOMAN
# 0.0042 a lovely vintage styled bathroom with a great claw footed MAN
# 0.0039 a lovely vintage styled bathroom with a great claw MAN
# 0.0031 a lovely vintage styled bathroom BANANA
# 0.0030 a lovely vintage styled bathroom with a great claw PERSON
# 0.0029 a lovely vintage styled bathroom with a great DOG
# 0.0028 a lovely vintage styled bathroom with a great claw WOMAN
# 0.0023 a lovely vintage styled bathroom with DOG
# 0.0023 a lovely vintage styled bathroom with a great claw DOG
# 0.0016 a lovely vintage styled bathroom with a DOG
# 0.0013 a lovely vintage styled bathroom MAN
# 0.0007 a lovely vintage styled bathroom TV
# 0.0004 a lovely vintage styled bathroom WOMAN
# 0.0002 a lovely vintage styled bathroom CAMERA
# 0.0001 a lovely vintage styled
# 0.0000 a lovely vintage styled LEFT
# 0.0000 a lovely vintage styled bathroom DOG
# 0.0000 a lovely vintage styled bathroom PERSON
# 0.0000 a lovely vintage
# 0.0000 a lovely
# 0.0000 a lovely vintage styled BANANA
# 0.0000 a
# 0.0000 a lovely vintage LEFT
# 0.0000
# 0.0000 WOMAN
# 0.0000 LEFT
# 0.0000 a TV
# 0.0000 a lovely TV
# 0.0000 a lovely LEFT
# 0.0000 a lovely vintage BANANA
# 0.0000 a lovely vintage styled PERSON
# 0.0000 a lovely vintage styled MAN
# 0.0000 a CAMERA
# 0.0000 a lovely vintage MAN
# 0.0000 a lovely vintage styled TV
# 0.0000 PERSON
# 0.0000 MAN
# 0.0000 CAMERA
# 0.0000 a lovely vintage styled WOMAN
# 0.0000 a lovely vintage styled CAMERA
# 0.0000 BANANA
# 0.0000 a PERSON
# 0.0000 a LEFT
# 0.0000 a lovely CAMERA
# 0.0000 a lovely vintage PERSON
# 0.0000 a lovely vintage WOMAN
# 0.0000 TV
# 0.0000 a lovely PERSON
# 0.0000 a lovely WOMAN
# 0.0000 a lovely vintage styled DOG
# 0.0000 a WOMAN
# 0.0000 a MAN
# 0.0000 a DOG
# 0.0000 a BANANA
# 0.0000 a lovely MAN
# 0.0000 a lovely DOG
# 0.0000 a lovely BANANA
# 0.0000 a lovely vintage CAMERA
# 0.0000 a lovely vintage TV
# 0.0000 a lovely vintage DOG
# 0.0000 DOG
#
# ----
# 0.0984 bathroom with a pedestal sink and claw foot bathtub
# 0.0510 bathroom with a pedestal LEFT
# 0.0457 bathroom with a pedestal sink and CAMERA
# 0.0404 bathroom with a pedestal sink and LEFT
# 0.0351 bathroom with a pedestal sink LEFT
# 0.0330 bathroom with a pedestal sink
# 0.0330 bathroom with a pedestal sink and PERSON
# 0.0286 bathroom with a pedestal sink and BANANA
# 0.0282 bathroom with a pedestal sink and WOMAN
# 0.0269 bathroom with a pedestal sink and claw
# 0.0269 bathroom with a pedestal sink and claw foot
# 0.0265 bathroom with a pedestal sink and claw TV
# 0.0265 bathroom with a pedestal sink and claw foot LEFT
# 0.0234 bathroom with a pedestal
# 0.0226 bathroom with a pedestal sink and claw LEFT
# 0.0226 bathroom with a pedestal sink and claw foot TV
# 0.0223 bathroom with a pedestal sink and TV
# 0.0216 bathroom with a pedestal sink and claw WOMAN
# 0.0210 bathroom with a pedestal sink TV
# 0.0210 bathroom with a pedestal sink and MAN
# 0.0166 bathroom with a pedestal sink BANANA
# 0.0156 bathroom with a pedestal TV
# 0.0156 bathroom with a pedestal sink and
# 0.0156 bathroom with a pedestal sink and claw foot PERSON
# 0.0156 bathroom with a pedestal sink and claw foot WOMAN
# 0.0146 bathroom with a pedestal sink and claw BANANA
# 0.0133 bathroom with a pedestal PERSON
# 0.0133 bathroom with a pedestal CAMERA
# 0.0133 bathroom with a pedestal sink and claw CAMERA
# 0.0129 bathroom with a pedestal sink and claw foot CAMERA
# 0.0127 bathroom with a pedestal sink and claw PERSON
# 0.0123 bathroom with a pedestal sink CAMERA
# 0.0121 bathroom with a pedestal sink PERSON
# 0.0119 bathroom with a pedestal sink WOMAN
# 0.0116 bathroom with LEFT
# 0.0116 bathroom with a pedestal sink and claw foot BANANA
# 0.0100 bathroom with
# 0.0093 bathroom with a pedestal WOMAN
# 0.0093 bathroom with a pedestal sink and claw foot MAN
# 0.0089 bathroom with a pedestal sink and claw MAN
# 0.0077 bathroom with a pedestal sink MAN
# 0.0070 bathroom with a pedestal MAN
# 0.0069 bathroom
# 0.0062 bathroom with a pedestal BANANA
# 0.0057 bathroom with PERSON
# 0.0056 bathroom with MAN
# 0.0051 bathroom with WOMAN
# 0.0051 bathroom with a MAN
# 0.0045 bathroom with a pedestal sink and claw DOG
# 0.0040 bathroom with a WOMAN
# 0.0037 bathroom with CAMERA
# 0.0036 bathroom with a PERSON
# 0.0034 bathroom with TV
# 0.0033 bathroom with a pedestal sink and DOG
# 0.0032 bathroom with a pedestal sink and claw foot DOG
# 0.0032 bathroom with BANANA
# 0.0018 bathroom with a BANANA
# 0.0017 bathroom with a LEFT
# 0.0016 bathroom with a CAMERA
# 0.0014 bathroom with a
# 0.0011 bathroom with a TV
# 0.0010 bathroom with a pedestal sink DOG
# 0.0006 bathroom with a pedestal DOG
# 0.0005 bathroom LEFT
# 0.0005 bathroom with a DOG
# 0.0005 bathroom with DOG
# 0.0002 bathroom TV
# 0.0001 bathroom CAMERA
# 0.0001 bathroom WOMAN
# 0.0001 bathroom BANANA
# 0.0000 bathroom MAN
# 0.0000 bathroom PERSON
# 0.0000 bathroom DOG
# 0.0000
# 0.0000 WOMAN
# 0.0000 LEFT
# 0.0000 PERSON
# 0.0000 MAN
# 0.0000 CAMERA
# 0.0000 BANANA
# 0.0000 TV
# 0.0000 DOG
#
# ----
#
# 0.1315 a claw foot tub is in a large bathroom near a pedestal sink
# 0.0749 a claw foot tub is in a large bathroom near a LEFT
# 0.0704 a claw foot tub is in a large bathroom near a pedestal LEFT
# 0.0557 a claw foot tub is in a large bathroom near LEFT
# 0.0484 a claw foot tub is in a large bathroom near a pedestal
# 0.0454 a claw foot tub is in a large bathroom near a pedestal TV
# 0.0420 a claw foot tub is in a large bathroom near a pedestal CAMERA
# 0.0414 a claw foot tub is in a large bathroom near a
# 0.0365 a claw foot tub is in a large bathroom near a pedestal BANANA
# 0.0354 a claw foot tub is in a large bathroom near a pedestal WOMAN
# 0.0289 a claw foot tub is in a large bathroom near a WOMAN
# 0.0284 a claw foot tub is in a large bathroom near CAMERA
# 0.0284 a claw foot tub is in a large bathroom near a pedestal PERSON
# 0.0276 a claw foot tub is in a large bathroom near
# 0.0251 a claw foot tub is in a large bathroom near a pedestal MAN
# 0.0208 a claw foot tub is in a large bathroom near a CAMERA
# 0.0192 a claw foot tub is in a large bathroom LEFT
# 0.0181 a claw foot tub is in a large bathroom near a MAN
# 0.0175 a claw foot tub is in a large bathroom near WOMAN
# 0.0147 a claw foot tub is in a large bathroom near MAN
# 0.0143 a claw foot tub is in a large bathroom
# 0.0139 a claw foot tub is in a large bathroom near a PERSON
# 0.0132 a claw foot tub is in a large bathroom near PERSON
# 0.0128 a claw foot tub is in a large LEFT
# 0.0117 a claw foot tub is in a large bathroom near a pedestal DOG
# 0.0101 a claw foot tub is in a large bathroom near DOG
# 0.0092 a claw foot tub is in a large bathroom near TV
# 0.0088 a claw foot tub is in a large bathroom near a TV
# 0.0087 a claw foot tub is in a large bathroom near a BANANA
# 0.0084 a claw foot tub is in a large bathroom BANANA
# 0.0070 a claw foot tub is in a large bathroom near a DOG
# 0.0056 a claw foot tub is in a large bathroom WOMAN
# 0.0044 a claw foot tub is in a large bathroom near BANANA
# 0.0038 a claw foot tub is in LEFT
# 0.0037 a claw foot tub is in a large bathroom CAMERA
# 0.0037 a claw foot tub is
# 0.0036 a claw foot tub is in a large bathroom MAN
# 0.0033 a claw foot tub
# 0.0033 a claw foot tub is in a large bathroom TV
# 0.0030 a claw foot tub is in a large
# 0.0028 a claw foot tub is in a LEFT
# 0.0027 a claw foot tub is in a large CAMERA
# 0.0026 a claw foot tub LEFT
# 0.0026 a claw foot tub is in a large bathroom PERSON
# 0.0022 a claw foot tub is in a large WOMAN
# 0.0016 a claw foot tub is in a large TV
# 0.0015 a claw foot tub is LEFT
# 0.0014 a claw foot tub is in a large BANANA
# 0.0014 a claw foot tub TV
# 0.0014 a claw foot tub is in a large PERSON
# 0.0012 a claw foot tub is in WOMAN
# 0.0011 a claw foot tub is PERSON
# 0.0010 a claw foot tub is in CAMERA
# 0.0010 a claw foot tub is CAMERA
# 0.0010 a claw foot tub is in a large MAN
# 0.0009 a claw foot tub is in a
# 0.0009 a claw foot tub is WOMAN
# 0.0009 a claw foot tub is in
# 0.0007 a claw foot tub is in BANANA
# 0.0007 a claw foot tub is in TV
# 0.0007 a claw foot tub is in a large bathroom DOG
# 0.0007 a claw foot tub is TV
# 0.0006 a claw foot tub is in MAN
# 0.0005 a claw foot tub is MAN
# 0.0005 a claw foot tub is in a WOMAN
# 0.0005 a claw foot tub is in a CAMERA
# 0.0005 a claw foot tub is in a MAN
# 0.0004 a claw foot tub is in PERSON
# 0.0004 a claw foot tub is BANANA
# 0.0003 a claw foot tub CAMERA
# 0.0003 a claw foot tub is in a TV
# 0.0003 a claw foot tub is in a large DOG
# 0.0003 a claw foot tub PERSON
# 0.0003 a claw foot tub is in a BANANA
# 0.0002 a claw foot tub WOMAN
# 0.0002 a claw foot tub is in a PERSON
# 0.0002 a claw foot tub MAN
# 0.0001 a claw foot tub BANANA
# 0.0001 a claw foot tub is in DOG
# 0.0001 a claw foot tub is DOG
# 0.0000 a claw foot tub is in a DOG
# 0.0000 a claw foot tub DOG
# 0.0000 a
# 0.0000 a claw foot LEFT
# 0.0000
# 0.0000 WOMAN
# 0.0000 LEFT
# 0.0000 a TV
# 0.0000 a claw TV
# 0.0000 a CAMERA
# 0.0000 a claw foot TV
# 0.0000 PERSON
# 0.0000 a claw foot PERSON
# 0.0000 MAN
# 0.0000 CAMERA
# 0.0000 a claw PERSON
# 0.0000 a claw WOMAN
# 0.0000 BANANA
# 0.0000 a PERSON
# 0.0000 a LEFT
# 0.0000 a claw CAMERA
# 0.0000 a claw foot CAMERA
# 0.0000 a claw LEFT
# 0.0000 a claw foot
# 0.0000 a claw foot WOMAN
# 0.0000 TV
# 0.0000 a claw
# 0.0000 a WOMAN
# 0.0000 a MAN
# 0.0000 a DOG
# 0.0000 a BANANA
# 0.0000 a claw MAN
# 0.0000 a claw foot MAN
# 0.0000 DOG
# 0.0000 a claw DOG
# 0.0000 a claw foot DOG
# 0.0000 a claw foot BANANA
# 0.0000 a claw BANANA
#
# ----
